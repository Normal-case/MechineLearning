# %%
'''
대회 이름 : 제주 신용카드 빅데이터
주제 : 신용카드 사용 내역 데이터를 활용한 지역별, 업종별 월간 카드 사용 총액 예측
배경 : 
- 신용카드 사용량 분석을 통한 'Post COVID-19 시대' 신용카드 사용량 예측 모델 개발
- 지역 경제 위축 및 중소상공인 경영난 해소를 위한 대책 마련

컬럼 : 
- REG_YYMM : 년월
- CARD_SIDO_NM : 카드이용지역_시도(가맹점 주소 기준)
- CARD_CCG_NM : 카드이용지역_시군구(가맹점 주소 기준)
- STD_CLSS_NM : 업종명
- HOM_SIDO_NM : 거주지역_시도(고객 집주소 기준)
- HOM_CCG_NM : 거주지역_시군구(고객 집주소 기준)
- AGE : 연령대
- SEX_CTGO_CD : 성별(1:남성,2:여성)
- FLC : 가구생애주기(1:1인가구, 2:영유아자녀가구, 3:중고생자녀가구, 4:성인자녀가구, 5:노년가구)
- CSTMR_CNT : 이용고객수(명)
- AMT : 이용금액(원)
- CNT : 이용건수(건)
'''
# Out:
# "\n대회 이름 : 제주 신용카드 빅데이터\n주제 : 신용카드 사용 내역 데이터를 활용한 지역별, 업종별 월간 카드 사용 총액 예측\n배경 : \n- 신용카드 사용량 분석을 통한 'Post COVID-19 시대' 신용카드 사용량 예측 모델 개발\n- 지역 경제 위축 및 중소상공인 경영난 해소를 위한 대책 마련\n\n컬럼 : \n- REG_YYMM : 년월\n- CARD_SIDO_NM : 카드이용지역_시도(가맹점 주소 기준)\n- CARD_CCG_NM : 카드이용지역_시군구(가맹점 주소 기준)\n- STD_CLSS_NM : 업종명\n- HOM_SIDO_NM : 거주지역_시도(고객 집주소 기준)\n- HOM_CCG_NM : 거주지역_시군구(고객 집주소 기준)\n- AGE : 연령대\n- SEX_CTGO_CD : 성별(1:남성,2:여성)\n- FLC : 가구생애주기(1:1인가구, 2:영유아자녀가구, 3:중고생자녀가구, 4:성인자녀가구, 5:노년가구)\n- CSTMR_CNT : 이용고객수(명)\n- AMT : 이용금액(원)\n- CNT : 이용건수(건)\n"

# %% [markdown]
# ### 한글텍스트

# %%
#그래프의 전체적인 설정을 하는 객체
import matplotlib as mpl
#그래프를 그리는 객체
import matplotlib.pyplot as plt

# %%
#그래프의 글자를 선명하게 출력하도록 설정 
# %config InlineBackend.figure_format = 'retina'
#나눔 글자체 설치 
# !apt -qq -y install fonts-nanum
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import matplotlib.font_manager as fm
#나눔고딕 글자체의 전체 경로 설정
fontpath = 'd'
#글자체의 경로와 글자 크기 설정
font = fm.FontProperties(fname=fontpath, size=9)

# %%
#폰트 이름 설정
plt.rc('font', family='NanumBarunGothic') 
#폰트 업데이트
mpl.font_manager._rebuild()

# %% [markdown]
# # 파일업로드

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
path = './drive/My Drive/인공지능 큐레이터/Machine Learning/data/'
df04 = pd.read_csv(path + '202004.csv')

# %%
y = df04['AMT']
X = df04.drop(['AMT'], axis = 1)
del df04

# %%
X_data, dummy1, y_target, dummy2 = train_test_split(X, y, test_size = 0.7, random_state = 777)
del dummy1
del dummy2
del X
del y

# %%
df04 = pd.concat([X_data, y_target], axis = 1)
df04
# Out:
#          REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT CNT      AMT
# 604782     202004           부산         기장군  ...         5   6   705100
# 1339385    202004           충북     청주시 흥덕구  ...        20  22  1297830
# 948595     202004           서울        영등포구  ...         3   3    26960
# 417741     202004           경남     창원시 성산구  ...         3   3    24200
# 1192749    202004           전북         완주군  ...         3   3    96992
# ...           ...          ...         ...  ...       ...  ..      ...
# 54941      202004           강원         횡성군  ...         3   3    48300
# 102321     202004           경기         구리시  ...         7  13   662000
# 106071     202004           경기         구리시  ...         3   3    12750
# 183206     202004           경기     수원시 영통구  ...         3   5    75355
# 474683     202004           경북         영주시  ...         3   3    93000
#
# [405096 rows x 12 columns]

# %%
del X_data
del y_target

# %%
# 19.01 ~ 20.03 데이터 업로드
dfRest = pd.read_csv(path + '201901-202003.csv')

# %%
y = dfRest['AMT']
X = dfRest.drop(['AMT'], axis = 1)

# %%
del dfRest

# %%
X_data, dummy1, y_target, dummy2 = train_test_split(X, y, test_size = 0.7, random_state = 777)

# %%
del X
del y
del dummy1
del dummy2

# %%
dfRest = pd.concat([X_data, y_target], axis = 1)

# %%
del X_data
del y_target
dfRest
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT  CNT       AMT
# 16222599    201910           부산          중구  ...         7    9    285300
# 7595004     201905           서울        동대문구  ...         3    3     36140
# 23487563    202003           강원         횡성군  ...         4    5    143980
# 19464950    201912           부산         강서구  ...        11   15   2130850
# 10777115    201907           부산          남구  ...         8   13    814130
# ...            ...          ...         ...  ...       ...  ...       ...
# 4419700     201903           서울         종로구  ...         6    8     49500
# 14782385    201909           서울         송파구  ...         3    3     12400
# 23251878    202002           전남         무안군  ...       223  738  16075180
# 23543355    202003           경기         군포시  ...        27  125    615740
# 18151527    201911           서울        서대문구  ...         3    3     86000
#
# [7409337 rows x 12 columns]

# %%
df = pd.concat([dfRest, df04])

# %%
del dfRest
del df04
df
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT CNT      AMT
# 16222599    201910           부산          중구  ...         7   9   285300
# 7595004     201905           서울        동대문구  ...         3   3    36140
# 23487563    202003           강원         횡성군  ...         4   5   143980
# 19464950    201912           부산         강서구  ...        11  15  2130850
# 10777115    201907           부산          남구  ...         8  13   814130
# ...            ...          ...         ...  ...       ...  ..      ...
# 54941       202004           강원         횡성군  ...         3   3    48300
# 102321      202004           경기         구리시  ...         7  13   662000
# 106071      202004           경기         구리시  ...         3   3    12750
# 183206      202004           경기     수원시 영통구  ...         3   5    75355
# 474683      202004           경북         영주시  ...         3   3    93000
#
# [7814433 rows x 12 columns]

# %% [markdown]
# # 결측치 처리

# %%
df.loc[df['CARD_SIDO_NM'] == '세종', 'CARD_CCG_NM'] = '세종구'
df.loc[df['HOM_SIDO_NM'] == '세종', 'HOM_CCG_NM'] = '세종구'
df
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT CNT      AMT
# 16222599    201910           부산          중구  ...         7   9   285300
# 7595004     201905           서울        동대문구  ...         3   3    36140
# 23487563    202003           강원         횡성군  ...         4   5   143980
# 19464950    201912           부산         강서구  ...        11  15  2130850
# 10777115    201907           부산          남구  ...         8  13   814130
# ...            ...          ...         ...  ...       ...  ..      ...
# 54941       202004           강원         횡성군  ...         3   3    48300
# 102321      202004           경기         구리시  ...         7  13   662000
# 106071      202004           경기         구리시  ...         3   3    12750
# 183206      202004           경기     수원시 영통구  ...         3   5    75355
# 474683      202004           경북         영주시  ...         3   3    93000
#
# [7814433 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7814433 entries, 16222599 to 474683
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  CNT           int64
#  11  AMT           int64
# dtypes: int64(6), object(6)
# memory usage: 775.1+ MB

# %%
df.isna().sum()
# Out:
# REG_YYMM        0
# CARD_SIDO_NM    0
# CARD_CCG_NM     0
# STD_CLSS_NM     0
# HOM_SIDO_NM     0
# HOM_CCG_NM      0
# AGE             0
# SEX_CTGO_CD     0
# FLC             0
# CSTMR_CNT       0
# CNT             0
# AMT             0
# dtype: int64

# %% [markdown]
# # CSTMR_CNT, CNT 제거

# %%
df.drop(['CSTMR_CNT', 'CNT'], axis = 1, inplace = True)

# %%
df
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... SEX_CTGO_CD FLC      AMT
# 16222599    201910           부산          중구  ...           2   5   285300
# 7595004     201905           서울        동대문구  ...           1   4    36140
# 23487563    202003           강원         횡성군  ...           2   3   143980
# 19464950    201912           부산         강서구  ...           2   5  2130850
# 10777115    201907           부산          남구  ...           2   2   814130
# ...            ...          ...         ...  ...         ...  ..      ...
# 54941       202004           강원         횡성군  ...           1   5    48300
# 102321      202004           경기         구리시  ...           2   5   662000
# 106071      202004           경기         구리시  ...           2   3    12750
# 183206      202004           경기     수원시 영통구  ...           1   1    75355
# 474683      202004           경북         영주시  ...           1   2    93000
#
# [7814433 rows x 10 columns]

# %% [markdown]
# # Label Encode

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7814433 entries, 16222599 to 474683
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   AMT           int64
# dtypes: int64(4), object(6)
# memory usage: 655.8+ MB

# %%
encoder.fit(df['CARD_SIDO_NM'])
df['CARD_SIDO_NM'] = encoder.transform(df['CARD_SIDO_NM'])
encoder.fit(df['CARD_CCG_NM'])
df['CARD_CCG_NM'] = encoder.transform(df['CARD_CCG_NM'])
encoder.fit(df['STD_CLSS_NM'])
df['STD_CLSS_NM'] = encoder.transform(df['STD_CLSS_NM'])
encoder.fit(df['HOM_SIDO_NM'])
df['HOM_SIDO_NM'] = encoder.transform(df['HOM_SIDO_NM'])
encoder.fit(df['HOM_CCG_NM'])
df['HOM_CCG_NM'] = encoder.transform(df['HOM_CCG_NM'])
encoder.fit(df['AGE'])
df['AGE'] = encoder.transform(df['AGE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7814433 entries, 16222599 to 474683
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  int64
#  2   CARD_CCG_NM   int64
#  3   STD_CLSS_NM   int64
#  4   HOM_SIDO_NM   int64
#  5   HOM_CCG_NM    int64
#  6   AGE           int64
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   AMT           int64
# dtypes: int64(10)
# memory usage: 655.8 MB

# %% [markdown]
# # 랜덤 포레스트 예측

# %%
y_target = df['AMT']
X_data = df.drop(['AMT'], axis = 1)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_target, test_size = 0.2, random_state = 0)

rf = RandomForestRegressor(random_state = 0, n_estimators = 10)

# %%
import time
import numpy as np
start = time.time()
rf.fit(X_train, y_train)
print(np.round(time.time() - start, 2))
# Out:
# 402.01

# %%
pred = rf.predict(X_test)

# %%
from sklearn.metrics import r2_score

print('Avg :', y_test.mean())
print('MSE :', mean_squared_error(y_test, pred))
print('RMSE :', mean_squared_error(y_test, pred)**0.5)
print('r2_score :', r2_score(y_test, pred))
# Out:
# Avg : 2466708.673082571
# MSE : 101641126930007.84
# RMSE : 10081722.418813555
# r2_score : 0.6903852161813387

# %% [markdown]
# # LightGBM

# %%
from lightgbm import LGBMRegressor
lgbm_wrapper = LGBMRegressor(n_estimators = 400)

# %%
evals = [(X_test, y_test)]
lgbm_wrapper.fit(X_train, y_train, eval_metric='logloss', eval_set = evals, verbose = True)
# Out:
# [1]	valid_0's l2: 3.27425e+14
# [2]	valid_0's l2: 3.26729e+14
# [3]	valid_0's l2: 3.26028e+14
# [4]	valid_0's l2: 3.25519e+14
# [5]	valid_0's l2: 3.25072e+14
# [6]	valid_0's l2: 3.24479e+14
# [7]	valid_0's l2: 3.23784e+14
# [8]	valid_0's l2: 3.22407e+14
# [9]	valid_0's l2: 3.20814e+14
# [10]	valid_0's l2: 3.19961e+14
# [11]	valid_0's l2: 3.19633e+14
# [12]	valid_0's l2: 3.17639e+14
# [13]	valid_0's l2: 3.17257e+14
# [14]	valid_0's l2: 3.15435e+14
# [15]	valid_0's l2: 3.14915e+14
# [16]	valid_0's l2: 3.1332e+14
# [17]	valid_0's l2: 3.12981e+14
# [18]	valid_0's l2: 3.11946e+14
# [19]	valid_0's l2: 3.11161e+14
# [20]	valid_0's l2: 3.09898e+14
# [21]	valid_0's l2: 3.09414e+14
# [22]	valid_0's l2: 3.09159e+14
# [23]	valid_0's l2: 3.07963e+14
# [24]	valid_0's l2: 3.07335e+14
# [25]	valid_0's l2: 3.06888e+14
# [26]	valid_0's l2: 3.05737e+14
# [27]	valid_0's l2: 3.05199e+14
# [28]	valid_0's l2: 3.05036e+14
# [29]	valid_0's l2: 3.04863e+14
# [30]	valid_0's l2: 3.04454e+14
# [31]	valid_0's l2: 3.04119e+14
# [32]	valid_0's l2: 3.04021e+14
# [33]	valid_0's l2: 3.03664e+14
# [34]	valid_0's l2: 3.03257e+14
# [35]	valid_0's l2: 3.02996e+14
# [36]	valid_0's l2: 3.02924e+14
# [37]	valid_0's l2: 3.02095e+14
# [38]	valid_0's l2: 3.01637e+14
# [39]	valid_0's l2: 3.01506e+14
# [40]	valid_0's l2: 3.00607e+14
# [41]	valid_0's l2: 3.00529e+14
# [42]	valid_0's l2: 3.00002e+14
