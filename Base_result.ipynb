# %%
'''
대회 이름 : 제주 신용카드 빅데이터
주제 : 신용카드 사용 내역 데이터를 활용한 지역별, 업종별 월간 카드 사용 총액 예측
배경 : 
- 신용카드 사용량 분석을 통한 'Post COVID-19 시대' 신용카드 사용량 예측 모델 개발
- 지역 경제 위축 및 중소상공인 경영난 해소를 위한 대책 마련

컬럼 : 
- REG_YYMM : 년월
- CARD_SIDO_NM : 카드이용지역_시도(가맹점 주소 기준)
- CARD_CCG_NM : 카드이용지역_시군구(가맹점 주소 기준)
- STD_CLSS_NM : 업종명
- HOM_SIDO_NM : 거주지역_시도(고객 집주소 기준)
- HOM_CCG_NM : 거주지역_시군구(고객 집주소 기준)
- AGE : 연령대
- SEX_CTGO_CD : 성별(1:남성,2:여성)
- FLC : 가구생애주기(1:1인가구, 2:영유아자녀가구, 3:중고생자녀가구, 4:성인자녀가구, 5:노년가구)
- CSTMR_CNT : 이용고객수(명)
- AMT : 이용금액(원)
- CNT : 이용건수(건)
'''
# Out:
# "\n대회 이름 : 제주 신용카드 빅데이터\n주제 : 신용카드 사용 내역 데이터를 활용한 지역별, 업종별 월간 카드 사용 총액 예측\n배경 : \n- 신용카드 사용량 분석을 통한 'Post COVID-19 시대' 신용카드 사용량 예측 모델 개발\n- 지역 경제 위축 및 중소상공인 경영난 해소를 위한 대책 마련\n\n컬럼 : \n- REG_YYMM : 년월\n- CARD_SIDO_NM : 카드이용지역_시도(가맹점 주소 기준)\n- CARD_CCG_NM : 카드이용지역_시군구(가맹점 주소 기준)\n- STD_CLSS_NM : 업종명\n- HOM_SIDO_NM : 거주지역_시도(고객 집주소 기준)\n- HOM_CCG_NM : 거주지역_시군구(고객 집주소 기준)\n- AGE : 연령대\n- SEX_CTGO_CD : 성별(1:남성,2:여성)\n- FLC : 가구생애주기(1:1인가구, 2:영유아자녀가구, 3:중고생자녀가구, 4:성인자녀가구, 5:노년가구)\n- CSTMR_CNT : 이용고객수(명)\n- AMT : 이용금액(원)\n- CNT : 이용건수(건)\n"

# %% [markdown]
# # 파일업로드

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
path = './drive/My Drive/인공지능 큐레이터/Machine Learning/data/'
df04 = pd.read_csv(path + '202004.csv')

# %%
y = df04['AMT']
X = df04.drop(['AMT'], axis = 1)
del df04

# %%
X_data, dummy1, y_target, dummy2 = train_test_split(X, y, test_size = 0.7, random_state = 777)
del dummy1
del dummy2
del X
del y

# %%
df04 = pd.concat([X_data, y_target], axis = 1)
df04
# Out:
#          REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT CNT      AMT
# 604782     202004           부산         기장군  ...         5   6   705100
# 1339385    202004           충북     청주시 흥덕구  ...        20  22  1297830
# 948595     202004           서울        영등포구  ...         3   3    26960
# 417741     202004           경남     창원시 성산구  ...         3   3    24200
# 1192749    202004           전북         완주군  ...         3   3    96992
# ...           ...          ...         ...  ...       ...  ..      ...
# 54941      202004           강원         횡성군  ...         3   3    48300
# 102321     202004           경기         구리시  ...         7  13   662000
# 106071     202004           경기         구리시  ...         3   3    12750
# 183206     202004           경기     수원시 영통구  ...         3   5    75355
# 474683     202004           경북         영주시  ...         3   3    93000
#
# [405096 rows x 12 columns]

# %%
del X_data
del y_target

# %%
# 19.01 ~ 20.03 데이터 업로드
dfRest = pd.read_csv(path + '201901-202003.csv')

# %%
y = dfRest['AMT']
X = dfRest.drop(['AMT'], axis = 1)

# %%
del dfRest

# %%
X_data, dummy1, y_target, dummy2 = train_test_split(X, y, test_size = 0.7, random_state = 777)

# %%
del X
del y
del dummy1
del dummy2

# %%
dfRest = pd.concat([X_data, y_target], axis = 1)

# %%
del X_data
del y_target
dfRest
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT  CNT       AMT
# 16222599    201910           부산          중구  ...         7    9    285300
# 7595004     201905           서울        동대문구  ...         3    3     36140
# 23487563    202003           강원         횡성군  ...         4    5    143980
# 19464950    201912           부산         강서구  ...        11   15   2130850
# 10777115    201907           부산          남구  ...         8   13    814130
# ...            ...          ...         ...  ...       ...  ...       ...
# 4419700     201903           서울         종로구  ...         6    8     49500
# 14782385    201909           서울         송파구  ...         3    3     12400
# 23251878    202002           전남         무안군  ...       223  738  16075180
# 23543355    202003           경기         군포시  ...        27  125    615740
# 18151527    201911           서울        서대문구  ...         3    3     86000
#
# [7409337 rows x 12 columns]

# %%
df = pd.concat([dfRest, df04])

# %%
del dfRest
del df04
df
# Out:
#           REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT CNT      AMT
# 16222599    201910           부산          중구  ...         7   9   285300
# 7595004     201905           서울        동대문구  ...         3   3    36140
# 23487563    202003           강원         횡성군  ...         4   5   143980
# 19464950    201912           부산         강서구  ...        11  15  2130850
# 10777115    201907           부산          남구  ...         8  13   814130
# ...            ...          ...         ...  ...       ...  ..      ...
# 54941       202004           강원         횡성군  ...         3   3    48300
# 102321      202004           경기         구리시  ...         7  13   662000
# 106071      202004           경기         구리시  ...         3   3    12750
# 183206      202004           경기     수원시 영통구  ...         3   5    75355
# 474683      202004           경북         영주시  ...         3   3    93000
#
# [7814433 rows x 12 columns]

# %%
df = df.sort_values(by = ['REG_YYMM','CARD_SIDO_NM', 'STD_CLSS_NM', 'CARD_CCG_NM', 'HOM_SIDO_NM'] )  # 정렬 기준 순서대로 정렬

# %%
df = df.reset_index(drop=True)   #인덱스 리셋
df
# Out:
#          REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT CNT      AMT
# 0          201901           강원         강릉시  ...        21  20  3573300
# 1          201901           강원         강릉시  ...         6   6   818700
# 2          201901           강원         강릉시  ...         3   3  1047300
# 3          201901           강원         동해시  ...        18  17  3521555
# 4          201901           강원         동해시  ...        10   8  1074190
# ...           ...          ...         ...  ...       ...  ..      ...
# 7814428    202004           충북         제천시  ...         4   5   752650
# 7814429    202004           충북         제천시  ...         3   4   284400
# 7814430    202004           충북         제천시  ...         3   3   178000
# 7814431    202004           충북         제천시  ...         3   4    77000
# 7814432    202004           충북         충주시  ...         6   6    92000
#
# [7814433 rows x 12 columns]

# %%
df.loc[df['CARD_SIDO_NM'] == '세종', 'CARD_CCG_NM'] = '세종구'
df.loc[df['HOM_SIDO_NM'] == '세종', 'HOM_CCG_NM'] = '세종구'
df
# Out:
#          REG_YYMM CARD_SIDO_NM CARD_CCG_NM  ... CSTMR_CNT CNT      AMT
# 0          201901           강원         강릉시  ...        21  20  3573300
# 1          201901           강원         강릉시  ...         6   6   818700
# 2          201901           강원         강릉시  ...         3   3  1047300
# 3          201901           강원         동해시  ...        18  17  3521555
# 4          201901           강원         동해시  ...        10   8  1074190
# ...           ...          ...         ...  ...       ...  ..      ...
# 7814428    202004           충북         제천시  ...         4   5   752650
# 7814429    202004           충북         제천시  ...         3   4   284400
# 7814430    202004           충북         제천시  ...         3   3   178000
# 7814431    202004           충북         제천시  ...         3   4    77000
# 7814432    202004           충북         충주시  ...         6   6    92000
#
# [7814433 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7814433 entries, 0 to 7814432
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  CNT           int64
#  11  AMT           int64
# dtypes: int64(6), object(6)
# memory usage: 715.4+ MB

# %%
df.isna().sum()
# Out:
# REG_YYMM        0
# CARD_SIDO_NM    0
# CARD_CCG_NM     0
# STD_CLSS_NM     0
# HOM_SIDO_NM     0
# HOM_CCG_NM      0
# AGE             0
# SEX_CTGO_CD     0
# FLC             0
# CSTMR_CNT       0
# CNT             0
# AMT             0
# dtype: int64

# %% [markdown]
# # 인코딩

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7814433 entries, 0 to 7814432
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  object
#  2   CARD_CCG_NM   object
#  3   STD_CLSS_NM   object
#  4   HOM_SIDO_NM   object
#  5   HOM_CCG_NM    object
#  6   AGE           object
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  CNT           int64
#  11  AMT           int64
# dtypes: int64(6), object(6)
# memory usage: 715.4+ MB

# %%
encoder.fit(df['CARD_SIDO_NM'])
df['CARD_SIDO_NM'] = encoder.transform(df['CARD_SIDO_NM'])
encoder.fit(df['CARD_CCG_NM'])
df['CARD_CCG_NM'] = encoder.transform(df['CARD_CCG_NM'])
encoder.fit(df['STD_CLSS_NM'])
df['STD_CLSS_NM'] = encoder.transform(df['STD_CLSS_NM'])
encoder.fit(df['HOM_SIDO_NM'])
df['HOM_SIDO_NM'] = encoder.transform(df['HOM_SIDO_NM'])
encoder.fit(df['HOM_CCG_NM'])
df['HOM_CCG_NM'] = encoder.transform(df['HOM_CCG_NM'])
encoder.fit(df['AGE'])
df['AGE'] = encoder.transform(df['AGE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7814433 entries, 0 to 7814432
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  int64
#  2   CARD_CCG_NM   int64
#  3   STD_CLSS_NM   int64
#  4   HOM_SIDO_NM   int64
#  5   HOM_CCG_NM    int64
#  6   AGE           int64
#  7   SEX_CTGO_CD   int64
#  8   FLC           int64
#  9   CSTMR_CNT     int64
#  10  CNT           int64
#  11  AMT           int64
# dtypes: int64(12)
# memory usage: 715.4 MB

# %%
df.drop(['CARD_CCG_NM', 'HOM_SIDO_NM', 'HOM_CCG_NM', 'AGE', 'SEX_CTGO_CD', 'FLC', 'CSTMR_CNT', 'CNT'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7814433 entries, 0 to 7814432
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   REG_YYMM      int64
#  1   CARD_SIDO_NM  int64
#  2   STD_CLSS_NM   int64
#  3   AMT           int64
# dtypes: int64(4)
# memory usage: 238.5 MB

# %% [markdown]
# # 랜덤 포레스트 예측

# %%
y_target = df['AMT']
X_data = df.drop(['AMT'], axis = 1)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_target, test_size = 0.2, random_state = 0)

rf = RandomForestRegressor(random_state = 0, n_estimators = 10)

# %%
import time
import numpy as np
start = time.time()
rf.fit(X_train, y_train)
print(np.round(time.time() - start, 2))
# Out:
# 106.81

# %%
pred = rf.predict(X_test)

# %%
from sklearn.metrics import r2_score

print('Avg :', y_test.mean())
print('MSE :', mean_squared_error(y_test, pred))
print('RMSE :', mean_squared_error(y_test, pred)**0.5)
print('r2_score :', r2_score(y_test, pred))
# Out:
# Avg : 2435859.954585328
# MSE : 290517442976670.0
# RMSE : 17044572.24387488
# r2_score : 0.010541757625413095

# %% [markdown]
# # 제출

# %%
subm = pd.read_csv(path + 'submission.csv')

# %%
subm
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM  AMT
# 0        0    202004           강원             건강보조식품 소매업    0
# 1        1    202004           강원                골프장 운영업    0
# 2        2    202004           강원            과실 및 채소 소매업    0
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업    0
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업    0
# ...    ...       ...          ...                    ...  ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업    0
# 1390  1390    202007           충북                한식 음식점업    0
# 1391  1391    202007           충북                    호텔업    0
# 1392  1392    202007           충북          화장품 및 방향제 소매업    0
# 1393  1393    202007           충북               휴양콘도 운영업    0
#
# [1394 rows x 5 columns]

# %%
subm.drop(['id'], axis = 1, inplace = True)

# %%
result = subm.copy()

# %%
encoder.fit(subm['REG_YYMM'])
subm['REG_YYMM'] = encoder.transform(subm['REG_YYMM'])
encoder.fit(subm['CARD_SIDO_NM'])
subm['CARD_SIDO_NM'] = encoder.transform(subm['CARD_SIDO_NM'])
encoder.fit(subm['STD_CLSS_NM'])
subm['STD_CLSS_NM'] = encoder.transform(subm['STD_CLSS_NM'])

# %%
subm.drop(['AMT'], axis = 1, inplace = True)

# %%
subm
# Out:
#       REG_YYMM  CARD_SIDO_NM  STD_CLSS_NM
# 0            0             0            0
# 1            0             0            1
# 2            0             0            2
# 3            0             0            3
# 4            0             0            4
# ...        ...           ...          ...
# 1389         1            16           36
# 1390         1            16           37
# 1391         1            16           38
# 1392         1            16           39
# 1393         1            16           40
#
# [1394 rows x 3 columns]

# %%
pred = rf.predict(subm)

# %%
pred
# Out:
# array([1602073.3253864 ,  614810.05571259,  732615.22745835, ...,
#         221609.42362757, 1418119.82004864,  460026.65831137])

# %%
result['AMT'] = pred

# %%
result
# Out:
#       REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0       202004           강원             건강보조식품 소매업  1.602073e+06
# 1       202004           강원                골프장 운영업  6.148101e+05
# 2       202004           강원            과실 및 채소 소매업  7.326152e+05
# 3       202004           강원      관광 민예품 및 선물용품 소매업  1.405880e+05
# 4       202004           강원   그외 기타 분류안된 오락관련 서비스업  1.312569e+05
# ...        ...          ...                    ...           ...
# 1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  5.510235e+05
# 1390    202007           충북                한식 음식점업  1.885326e+06
# 1391    202007           충북                    호텔업  2.216094e+05
# 1392    202007           충북          화장품 및 방향제 소매업  1.418120e+06
# 1393    202007           충북               휴양콘도 운영업  4.600267e+05
#
# [1394 rows x 4 columns]

# %%
result.to_csv('./result.csv', sep = ',')
